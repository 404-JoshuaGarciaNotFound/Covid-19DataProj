# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('county_population_2019.csv')
df
# Out:
#                                   Census Estimates Base         2010  \
# United States                308,745,538    308,758,105  309,321,666
# .Autauga County, Alabama          54,571         54,597       54,773
# .Baldwin County, Alabama         182,265        182,265      183,112
# .Barbour County, Alabama          27,457         27,455       27,327
# .Bibb County, Alabama             22,915         22,915       22,870
# ...                                  ...            ...          ...
# .Sweetwater County, Wyoming       43,806         43,806       43,574
# .Teton County, Wyoming            21,294         21,298       21,296
# .Uinta County, Wyoming            21,118         21,121       21,089
# .Washakie County, Wyoming          8,533          8,528        8,530
# .Weston County, Wyoming            7,208          7,208        7,198
#
#                                     2011         2012         2013  \
# United States                311,556,874  313,830,990  315,993,715
# ...

# %%
county_population_2019 = df['2019']
county_population_2019
# Out:
# United States                  328,239,523
# .Autauga County, Alabama            55,869
# .Baldwin County, Alabama           223,234
# .Barbour County, Alabama            24,686
# .Bibb County, Alabama               22,394
#                                   ...
# .Sweetwater County, Wyoming         42,343
# .Teton County, Wyoming              23,464
# .Uinta County, Wyoming              20,226
# .Washakie County, Wyoming            7,805
# .Weston County, Wyoming              6,927
# Name: 2019, Length: 3143, dtype: object
